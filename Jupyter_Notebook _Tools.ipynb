# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook contains basic data science tasks including languages,tools,libraries and simple python operation

# %% [markdown]
# Some of the popular languages that Data Science use are: abs
# 1. Python
# 2. SQL
# 3. R
# 4. VBA
# 5. JavaScript

# %% [markdown]
# Some of the commonly used libraries in Data Science include:
# 1. Numpy
# 2. Pandas
# 3. Scikit-learn
# 4. Matplotlib
# 5. Keras
# 6. TensorFlow
# 7. Seaborn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Anaconda           |
# | Jupyter Notebook   |
# | RStudio            |
# | Spyder             |
# | Zeppelin           |

# %% [markdown]
# ### Below are few examples of evaluating arithmetic expressions in Python

# %%
#This is a single arithmatic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minute to hours by dividing by 60
200//60
# Out:
# 3

# %% [markdown]
# ### Objectives:
#
# - Add comments to code
# - Create markdown cells
# - Add ordered and unordered lists to markdown cells
# - Format content in markdown cells with heading styles

# %% [markdown]
# **Author(s)**
# Priyanka
